# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# +2348090179535 (Mobile)
# dahunsi.fehinti@gmail.com
# www.linkedin.com/in/fehintoluwa-
# dahunsi (LinkedIn)
# Top Skills
# Business Strategy
# IT Strategy
# Project Management
# Languages
# English (Native or Bilingual)
# Spanish (Elementary)
# Yoruba (Limited Working)
# Certifications
# Certified Kubernetes Application
# Developer
# Career Essentials in Generative AI
# by Microsoft and LinkedIn
# Learn with NVIDIA and Andela
# Project Management Professional
# (PMP) (in view)
# Andela React Learning Program
# Honors-Awards
# Delegate, Lagos - Finland
# Educational Exchange Program
# Best Graduating Student, ICT
# Fehintoluwa Dahunsi
# Technical Program Manager | AI Engineering Leader | Quality
# Engineering | GCP PCA & AWS Certified & CKAD | Speaker &
# Mentor | Driving Cross-Functional Delivery, Scalable Automation &
# AI Transformation
# Lagos State, Nigeria
# Summary
# I build systems. I read wuxia. I solve problems.
# I enjoy deep-diving into processes and tackling the thorny questions
# of continuous improvement. I live for challenges that wake me up at
# 2 am yelling "Eureka" and send me dashing to my laptop to create
# solutions.
# People. Over. Process
# I enjoy people. My dream environment is a brilliant team with
# driven professionals that genuinely enjoy working with each other
# and value each other's expertise and viewpoints. I value constant
# constructive feedback. I subscribe to 360-degree leadership, the
# concept that leadership is irrespective of your position, the best
# leaders lead across, below, and upwards wherever they are placed
# in an organization.
# I am amazed by the ways processes like Agile are redefining the
# SDLC, and how these changes more and more demand the creation
# of quality assurance automation processes that are robust and
# flexible enough to support and enable the frenetic pace of modern
# software development. I conceived and built the foundations of the
# test automation framework within my first 4 months at my previous
# company.
# I am very much in a learning phase in my career, therefore I am
# interested in opportunities that challenge me more and more and
# enable me to broaden my horizons.
# Reach out! I'd love to hear from you, exchange anecdotes, and swap
# QA war stories :)
#   Page 1 of 4
# Experience
# Yattir Labs
# Technical Program Manager, AI & Automation
# August 2025 - Present (6 months)
# Lagos State, Nigeria
# Siemens Energy
# Senior Software Engineer, Grid Enhancing Technologies
# March 2024 - Present (1 year 11 months)
# Erlangen, Bavaria, Germany
# I define quality standards for the AssetGuard suite, creating and advocating
# adopting processes that enhance product quality.
# Andela
# Senior Software Engineer
# May 2021 - Present (4 years 9 months)
# Remote
# Bread Financial
# Senior Software Developer in Test
# January 2022 - July 2023 (1 year 7 months)
# Ohio, United States
# I lead quality efforts for a number of vital internal products affecting a
# significant number of services and merchants. A few notable products are
# Feature Flags: A service used by hundreds of thousands of users daily. I
# led quality efforts for this product, with less than 2% production error rates.
# Worked with the product team to create the test plan, executed test cases,
# authored automated tests, and maintained test pipelines for UI and API tests.
# Data Sharing and Integration: A vital service for providing real-time information
# to subscribers. I led quality efforts for this product, including researching and
# authoring custom plugins to enable automated testing.
# Created the test plan, executed test cases, authored automated tests, and
# created and maintained test pipelines for UI and API tests.
# I also communicate product quality status updates to stakeholders.
# Report directly to Senior Manager, Quality Engineering.
#   Page 2 of 4
# New Classrooms
# Senior Software Developer In Test
# June 2021 - February 2022 (9 months)
# New York, United States
# I led the refactoring of a legacy test codebase, reviving the framework and
# improving test coverage by 400%
# Yattir Consultancy
# 4 years 1 month
# Project Manager
# March 2020 - January 2021 (11 months)
# Lagos, Nigeria
# I seek out and acquire new business opportunities for the firm. I also grow
# existing businesses. I grew the computer hardware sale business by over
# 300% in 6 months. Leveraging top-notch communication and teamwork skills,
# I often serve as the first point of contact for new clients to the firm. I evaluate
# client business requirements and direct appropriate teams to fulfill client
# orders.
# Lead Software Engineer
# January 2017 - February 2020 (3 years 2 months)
# Lagos, Nigeria
# I wore many hats with Yattir. Lead developer, marketer, recruiter :).  Worked
# with a talented team on a lot of amazing projects and loved every second of it!
# I secured contracts with high-net-worth clients which created a 30% increase
# in YoY revenue by leveraging marketing skills and corporate connections. I led
# and often recruited multiple cross-functional teams of 3 - 5 contract/freelance
# staff and we consistently delivered top-notch quality software projects for
# clients.
# Trilogy
# Quality Assurance Engineer
# August 2020 - October 2020 (3 months)
# Texas, United States
# I create end to end test plans for 24+ enterprise products and present detailed
# reports to engineering teams enabling the rapid creation and weekly release of
# high-quality software product features
# Achieved 100% quality within 4 weeks of joining by employing best practices
# such as Root Cause Analysis, Deep Work blocks and Time Motion Studies.
#   Page 3 of 4
# Collaborate effectively with a remote team spread across 10+ countries,
# including creating mutual support groups for new batches of employees
# ALAT by Wema
# Quality Assurance Automation Engineer
# March 2020 - August 2020 (6 months)
# Lagos, Nigeria
# I've discovered I have quite the knack for continuously spotting ways to
# improve products and processes, and helping drive teams to implement these
# improvements.
# I collaborated with multiple cross-functional agile teams to redesign and build
# a revolutionary digital bank used by over one million daily active users, using
# cutting-edge technologies deployed on robust cloud infrastructure. I led the
# design and implementation of a test automation framework from scratch for our
# cross-platform mobile app and web platform.
# C#, Specflow, Selenium and Cypress, hosted on Azure
# Education
# University of Ibadan
# Bachelor of Science - B.Sc, Computer Science
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Fehintoluwa Dahunsi"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Fehintoluwa Dahunsi. You are answering questions on Fehintoluwa Dahunsi\'s website, particularly questions related to Fehintoluwa Dahunsi\'s career, background, skills and experience. Your responsibility is to represent Fehintoluwa Dahunsi for interactions on the website as faithfully as possible. You are given a summary of Fehintoluwa Dahunsi\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Ed Donner. I\'m an entrepreneur, software engineer and data scientist. I\'m originally from London, England, but I moved to NYC in 2000.\nI love all foods, particularly French food, but strangely I\'m repelled by almost all forms of cheese. I\'m not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n+2348090179535 (Mobile)\ndahunsi.fehinti@gmail.com\nwww.linkedin.com/in/fehintoluwa-\ndahunsi (LinkedIn)\nTop Skills\nBusiness Strategy\nIT Strategy\nProject Management\nLanguages\nEnglish (Native or Bilingual)\nSpanish (Elementary)\nYoruba (Limited Working)\nCertifications\nCertified Kubernetes Application\nDeveloper\nCareer Essentials in Generative AI\nby Microsoft and LinkedIn\nLearn with NVIDIA and Andela\nProject Management Professional\n(PMP) (in view)\nAndela React Learning Program\nHonors-Awards\nDelegate, Lagos - Finland\nEducational Exchange Program\nBest Graduating Student, ICT\nFehintoluwa Dahunsi\nTechnical Program Manager | AI Engineering Leader | Quality\nEngineering | GCP PCA & AWS Certified & CKAD | Speaker &\nMentor | Driving Cross-Functional Delivery, Scalable Automation &\nAI Transformation\nLagos State, Nigeria\nSummary\nI build systems. I read wuxia. I solve problems. \nI enjoy deep-diving into processes and tackling the thorny questions\nof continuous improvement. I live for challenges that wake me up at\n2 am yelling "Eureka" and send me dashing to my laptop to create\nsolutions.\nPeople. Over. Process\nI enjoy people. My dream environment is a brilliant team with\ndriven professionals that genuinely enjoy working with each other\nand value each other\'s expertise and viewpoints. I value constant\nconstructive feedback. I subscribe to 360-degree leadership, the\nconcept that leadership is irrespective of your position, the best\nleaders lead across, below, and upwards wherever they are placed\nin an organization.\nI am amazed by the ways processes like Agile are redefining the\nSDLC, and how these changes more and more demand the creation\nof quality assurance automation processes that are robust and\nflexible enough to support and enable the frenetic pace of modern\nsoftware development. I conceived and built the foundations of the\ntest automation framework within my first 4 months at my previous\ncompany.\nI am very much in a learning phase in my career, therefore I am\ninterested in opportunities that challenge me more and more and\nenable me to broaden my horizons.\nReach out! I\'d love to hear from you, exchange anecdotes, and swap\nQA war stories :)\n\xa0 Page 1 of 4\xa0 \xa0\nExperience\nYattir Labs\nTechnical Program Manager, AI & Automation\nAugust 2025\xa0-\xa0Present\xa0(6 months)\nLagos State, Nigeria\nSiemens Energy\nSenior Software Engineer, Grid Enhancing Technologies\nMarch 2024\xa0-\xa0Present\xa0(1 year 11 months)\nErlangen, Bavaria, Germany\nI define quality standards for the AssetGuard suite, creating and advocating\nadopting processes that enhance product quality.\nAndela\nSenior Software Engineer\nMay 2021\xa0-\xa0Present\xa0(4 years 9 months)\nRemote\nBread Financial\nSenior Software Developer in Test\nJanuary 2022\xa0-\xa0July 2023\xa0(1 year 7 months)\nOhio, United States\nI lead quality efforts for a number of vital internal products affecting a\nsign ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
