# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If five machines take five minutes to make five widgets, how long would 100 machines take to make 100 widgets?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# - **Given:**
#   Five machines take five minutes to make five widgets.
#
# - **Question:**
#   How long would 100 machines take to make 100 widgets?
#
# ---
#
# ### Step 1: Understand the rate per machine
#
# If 5 machines make 5 widgets in 5 minutes, then:
#
# - Total widgets made: 5 widgets
# - Total time taken: 5 minutes
# - Number of machines: 5
#
# Assuming each machine works at the same rate, let's find how many widgets one machine makes in 5 minutes.
#
# - Widgets per machine in 5 minutes = Total widgets / Number of machines = 5 / 5 = 1 widget
#
# So, **one machine makes 1 widget in 5 minutes**.
#
# ---
#
# ### Step 2: Determine how long it takes one machine to make one widget
#
# From above, one machine makes 1 widget in 5 minutes.
#
# ---
#
# ### Step 3: Find the time for 100 machines to make 100 widgets
#
# Since each machine makes 1 widget in 5 minutes:
#
# - 100 machines working simultaneously can each make 1 widget in 5 minutes, totaling 100 widgets.
# - Therefore, 100 machines would take **5 minutes** to make 100 widgets.
#
# ---
#
# ### **Answer:**
#
# **5 minutes**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# - **Given:**
#   Five machines take five minutes to make five widgets.
#
# - **Question:**
#   How long would 100 machines take to make 100 widgets?
#
# ---
#
# ### Step 1: Understand the rate per machine
#
# If 5 machines make 5 widgets in 5 minutes, then:
#
# - Total widgets made: 5 widgets
# - Total time taken: 5 minutes
# - Number of machines: 5
#
# Assuming each machine works at the same rate, let's find how many widgets one machine makes in 5 minutes.
#
# - Widgets per machine in 5 minutes = Total widgets / Number of machines = 5 / 5 = 1 widget
#
# So, **one machine makes 1 widget in 5 minutes**.
#
# ---
#
# ### Step 2: Determine how long it takes one machine to make one widget
#
# From above, one machine makes 1 widget in 5 minutes.
#
# ---
#
# ### Step 3: Find the time for 100 machines to make 100 widgets
#
# Since each machine makes 1 widget in 5 minutes:
#
# - 100 machines working simultaneously can each make 1 widget in 5 minutes, totaling 100 widgets.
# - Therefore, 100 machines would take **5 minutes** to make 100 widgets.
#
# ---
#
# ### **Answer:**
#
# **5 minutes**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area in nigeria that would be worth exploring for an agentic AI opportunity"}]

# Then make the first call:
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# One promising business area in Nigeria for an agentic AI opportunity is **agriculture**, specifically **precision farming and supply chain optimization**.
#
# ### Why Agriculture?
#
# 1. **Economic Significance:** Agriculture contributes about 24% to Nigeria’s GDP and employs a significant portion of the population.
# 2. **Challenges Faced:** Many smallholder farmers face issues such as low yields, unpredictable weather patterns, pest infestations, and inefficient distribution networks.
# 3. **Technology Gap:** There’s limited access to timely, actionable data and intelligent decision support tools.
#
# ### Potential Agentic AI Opportunities in Nigerian Agriculture
#
# - **Precision Farming Assistants:** AI agents could autonomously gather and analyze data from IoT sensors (soil moisture, nutrients, weather conditions) to recommend optimal planting times, irrigation schedules, and fertilizer application.
# - **Pest and Disease Detection:** AI-powered image recognition agents could monitor crops via drones or smartphones to detect early signs of pests or diseases and autonomously alert farmers or initiate countermeasures.
# - **Supply Chain Coordination:** Agentic AI could optimize logistics and distribution by coordinating between producers, middlemen, transporters, and markets to reduce post-harvest losses and ensure fair pricing.
# - **Financial and Insurance Services Automation:** AI agents could help assess creditworthiness of farmers, autonomously process microloans, and manage agricultural insurance claims using real-time data.
#
# ### Impact Potential
#
# - Increase crop yields and farm incomes.
# - Reduce food wastage and improve food security.
# - Empower smallholder farmers with AI-driven decision-making.
# - Create scalable solutions suitable for other African countries with similar challenges.
#
# ---
#
# If you want, I can also provide ideas in other sectors like fintech, healthcare, or energy!

# %%
message = f'''You are presented with a business idea for agentic ai in a particular industry. 
analyse the problem and identify a pain point in that industry which is ripe for an agentic solution
Here is the business idea:
{business_idea}
Reply with just the pain point
'''


messages = [{"role": "user","content": message}]

print(messages)
# Out:
# [{'role': 'user', 'content': 'You are presented with a business idea for agentic ai in a particular industry. \nanalyse the problem and identify a pain point in that industry which is ripe for an agentic solution\nHere is the business idea:\nOne promising business area in Nigeria for an agentic AI opportunity is **agriculture**, specifically **precision farming and supply chain optimization**.\n\n### Why Agriculture?\n\n1. **Economic Significance:** Agriculture contributes about 24% to Nigeria’s GDP and employs a significant portion of the population.\n2. **Challenges Faced:** Many smallholder farmers face issues such as low yields, unpredictable weather patterns, pest infestations, and inefficient distribution networks.\n3. **Technology Gap:** There’s limited access to timely, actionable data and intelligent decision support tools.\n\n### Potential Agentic AI Opportunities in Nigerian Agriculture\n\n- **Precision Farming Assistants:** AI agents could autonomously gather and analyze data from IoT sensors (soil moisture, nutrients, weather conditions) to recommend optimal planting times, irrigation schedules, and fertilizer application.\n- **Pest and Disease Detection:** AI-powered image recognition agents could monitor crops via drones or smartphones to detect early signs of pests or diseases and autonomously alert farmers or initiate countermeasures.\n- **Supply Chain Coordination:** Agentic AI could optimize logistics and distribution by coordinating between producers, middlemen, transporters, and markets to reduce post-harvest losses and ensure fair pricing.\n- **Financial and Insurance Services Automation:** AI agents could help assess creditworthiness of farmers, autonomously process microloans, and manage agricultural insurance claims using real-time data.\n\n### Impact Potential\n\n- Increase crop yields and farm incomes.\n- Reduce food wastage and improve food security.\n- Empower smallholder farmers with AI-driven decision-making.\n- Create scalable solutions suitable for other African countries with similar challenges.\n\n---\n\nIf you want, I can also provide ideas in other sectors like fintech, healthcare, or energy!\nReply with just the pain point\n'}]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the pain point:

pain_point = response.choices[0].message.content

print(pain_point)
# Out:
# Smallholder farmers lack access to timely, actionable data and intelligent decision support tools, leading to low crop yields, ineffective pest and disease management, and inefficiencies in logistics and distribution that cause high post-harvest losses.

# %%
message = f'''You are presented with a pain point in a particular industry. 
analyse the problem and cone up with an agentic AI solution to address the pain point
Here is the pain point:
{pain_point}
'''


messages = [{"role": "user","content": message}]

print(messages)  

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the pain point:

pain_point = response.choices[0].message.content

print(pain_point)
# Out:
# [{'role': 'user', 'content': 'You are presented with a pain point in a particular industry. \nanalyse the problem and cone up with an agentic AI solution to address the pain point\nHere is the pain point:\nSmallholder farmers lack access to timely, actionable data and intelligent decision support tools, leading to low crop yields, ineffective pest and disease management, and inefficiencies in logistics and distribution that cause high post-harvest losses.\n'}]
# Certainly! Let me analyze the pain point and then propose an agentic AI-driven solution.
#
# ---
#
# ### Pain Point Analysis
#
# **Industry:** Smallholder agriculture (typically small-scale farmers)
#
# **Key issues:**
#
# 1. **Lack of timely, actionable data:**
#    - Smallholder farmers often do not have access to real-time weather updates, soil health data, crop growth monitoring, and market prices.
#    - Limited access to localized, precise agricultural information hampers decision-making.
#
# 2. **Absence of intelligent decision support tools:**
#    - Farmers may not have expert knowledge or advisory services on best practices for pest and disease management.
#    - Limited digital tools or accessible platforms for guidance on crop selection, fertilization schedules, or irrigation.
#
# 3. **Inefficiencies in logistics and distribution:**
#    - Post-harvest losses are high due to poor storage, transportation bottlenecks, and lack of coordination among stakeholders.
#    - Fragmented supply chains mean produce is often sold at low prices or wasted.
#
# ---
#
# ### Agentic AI Solution Proposal: **AgriSense AI - an Autonomous Digital Farming Assistant**
#
# **Goal:** Empower smallholder farmers by providing them with an all-in-one, AI-driven decision support and supply chain coordination system that actively engages with the farmer and other stakeholders to improve yields, reduce losses, and increase incomes.
#
# ---
#
# ### Solution Components
#
# 1. **Data Gathering & Sensor Integration**
#
# - Deploy low-cost IoT devices (soil moisture sensors, weather stations, pest traps with image sensors) and integrate satellite/drone imagery.
# - Mobile app interface for farmers to input observations, crop details, and pest sightings.
#
# 2. **Agentic AI Decision Assistant**
#
# - **Personalized Crop Management:** AI model uses multi-source data (soil, weather, crop conditions) to generate timely alerts and recommendations for irrigation, fertilization, pest control, and disease mitigation.
# - **Pest and Disease Identification:** Using image recognition on photos taken by farmers, AI diagnoses issues and suggests targeted interventions (organic or chemical).
# - **Market Intelligence:** Analyzes local market prices, demand trends; suggests optimal time and place to sell produce to maximize profits.
# - **Logistics Optimization:** Coordinates with local transport providers and storage facilities to reserve space, negotiate costs, and plan optimal pickup routes to reduce post-harvest losses.
#
# 3. **Autonomous Interaction and Action**
#
# - The AI agent proactively engages with the farmer through voice/text chatbots in local languages, reminding about actions (e.g., irrigation schedules or spraying).
# - The system autonomously places orders for inputs (seeds, fertilizers, approved pesticides) through incorporated marketplace partnerships, if farmer consents.
# - In coordination with cooperatives, the agent schedules logistics and transport autonomously, ensuring timely collection and delivery to buyers or processors.
#
# 4. **Community and Learning Platform**
#
# - Farmers share success stories and tips; AI curates and amplifies verified best practices.
# - AI continuously learns from aggregated farm data to improve recommendations and detect emerging pests/diseases early.
#
# ---
#
# ### Benefits
#
# - **Increased Yields:** Data-driven interventions optimized for local conditions improve productivity.
# - **Better Pest/Disease Management:** Precise diagnosis and tailored suggestions reduce crop losses.
# - **Reduced Post-Harvest Losses:** Streamlined logistics lower wastage and improve earnings.
# - **Empowered Farmers:** Accessible, localized, and actionable insights improve decision-making independence.
# - **Scalability:** Modular system can grow to serve cooperatives, aggregators, and policymakers.
#
# ---
#
# ### Summary
#
# **AgriSense AI is an agentic AI solution combining real-time data acquisition, intelligent decision-making, autonomous engagement, and supply chain orchestration to address critical gaps faced by smallholder farmers. By embedding itself as a proactive digital assistant working closely with farmers and stakeholders, it can transform smallholder agriculture toward greater productivity and sustainability.**
#
# ---
#
# If you'd like, I can help flesh out technical architecture, deployment strategies, or business models for this solution.
